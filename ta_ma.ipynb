# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
df = pd.read_csv("eurusd.csv",parse_dates=["Date"],index_col="Date")

# %%
df.tail(15)

# %%
df.info()

# %%
df.plot(figsize=(12,8),title = "EUR/USD", fontsize= 12)
plt.show()

# %%
df

# %%
df["returns"] = np.log(df.div(df.shift(1)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df["returns"] = np.log(df.div(df.shift(1)))
#
# File c:\Users\phili\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3940, in DataFrame.__setitem__(self, key, value)
#    3938     self._setitem_array(key, value)
#    3939 elif isinstance(value, DataFrame):
# -> 3940     self._set_item_frame_value(key, value)
#    3941 elif (
#    3942     is_list_like(value)
#    3943     and not self.columns.is_unique
#    3944     and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    3945 ):
#    3946     # Column to set is duplicated
#    3947     self._setitem_array([key], value)
#
# File c:\Users\phili\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4069, in DataFrame._set_item_frame_value(self, key, value)
# ...

# %%
df.dropna(inplace = True)

# %%
df.returns.hist(bins = 100, figsize= (12,8))
plt.title("EUR/USD")
plt.show()

# %%
df.returns.sum()
# Out:
# -0.11214302770699758

# %%
np.exp(df.returns.sum())
# Out:
# 0.8939163935445148

# %%
df.price[-1] / df.price[0]
# Out:
# 0.8939163935445141

# %%
df.returns.cumsum().apply(np.exp)
# Out:
# Date
# 2004-01-02    1.000000
# 2004-01-05    1.008348
# 2004-01-06    1.011055
# 2004-01-07    1.004690
# 2004-01-08    1.015343
#                 ...
# 2020-06-24    0.899094
# 2020-06-25    0.894208
# 2020-06-26    0.891920
# 2020-06-29    0.892221
# 2020-06-30    0.893916
# Name: returns, Length: 4274, dtype: float64

# %%
df["creturns"] = df.returns.cumsum().apply(np.exp)

# %%
df.creturns.plot(figsize=(12,8),title="EUR - Buy and hold", fontsize=12)
plt.show()
